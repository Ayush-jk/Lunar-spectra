# %% [markdown]
# # Lunar Spectra — Main Runner
# Executes all modules in sequence in a single kernel.
# All variables are shared across modules — no intermediate files needed.
#
# | Notebook | Purpose |
# |---|---|
# | 01_data_loading | Install libs, mount Drive, load IIRS scene |
# | 02_eda | Reflectance plots, grayscale bands, geo-coordinates |
# | 03_preprocessing | Normalize, flatten, PCA (10 components, 98.3% variance) |
# | 04_clustering | K-Means (k=5), cluster visualization |
# | 05_classification | CNN train/eval, spatial generalization, save artifacts |
# | 06_analysis | Full scene prediction, spectral validation, band depth analysis |

# %%
# %run modules/01_data_loading.ipynb

# %%
# %run modules/02_eda.ipynb

# %%
# %run modules/03_preprocessing.ipynb

# %%
# %run modules/04_clustering.ipynb

# %%
# %run modules/05_classification.ipynb

# %%
# %run modules/06_analysis.ipynb

# %% [markdown]
# ---
# All outputs saved to `images/hyperspectral/` and model artifacts to Google Drive.
